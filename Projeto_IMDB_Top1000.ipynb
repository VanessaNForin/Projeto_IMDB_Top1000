# %% [markdown]
# <a href="https://colab.research.google.com/github/VanessaNForin/Projeto_IMDB_Top1000/blob/main/Projeto_IMDB_Top1000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Descrição Geral do Projeto
#
# ---
#
# ##**O que é o IMDB?**
#
# <img width=300 src = 'https://m.media-amazon.com/images/G/01/imdb/images/social/imdb_logo.png'>
#
# Conhecida como um ponto de referência para os fãs de cinema, o *Internet Movie Data Base*, conhecido popularmente como *IMDB*, é um website que fornece informações completas sobre filmes, bem como sobre séries, músicas e games. Além disse, permite aos usuários a avaliar as produções audiovisuais.
# Atualmente, é propriedade da Amazon.
#
# ##**Sobre o DataSet**
#
# O IMDB conta com uma lista dos 1000 melhores filmes definido pelas avaliações dos usuários em seu site oficial.
# No Kaggle, plataforma de Ciência de Dados e Inteligência Artificial, a lista em formato de DataFrame pode ser encontrada no link abaixo:
#
# **[IMDB Movies Dataset](https://www.kaggle.com/datasets/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows/data)**
#
# **IMPORTANTE**: A presente investigação foi realizada entre os meses 11 e 12 de 2024. Sendo assim as informações no DataFrame podem mudar conforme o passar do tempo
#
# ##**Motivação**
#
# A principal motivação para esse projeto é expressar meus conhecimentos acadêmicos. Esse projeto focará principalmente no uso da Biblioteca Pandas.
# Além disso, o projeto faz parte do meu portfólio pessoal para a área de Ciência de Dados.
#
# ###**BOA LEITURA** 🙂

# %% [markdown]
# #Configurações Iniciais

# %%
#Importando a Biblioteca Pandas e fazendo conexão com o Drive

import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Importando e Lendo a Base de Dados

imdbtop100_url = '/content/drive/MyDrive/imdb_top_1000.csv'

df_imdb_top = pd.read_csv(imdbtop100_url)

# %%
df_imdb_top
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df_imdb_top.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
df_imdb_top.shape
# Out:
# (1000, 16)

# %%
df_imdb_top.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %% [markdown]
# **<h2>Análise Inicial da Base de Dados</h2>**
#
# ---
#
# Após importar a base de dados em formato CSV, conseguimos obter algumas informações gerais sobre o Data Frame.
#
# O Data Frame contém 1000 linhas e 16 colunas.
#
# Abaixo, retirado da própria fonte no Kaggle, está o nome das colunas e suas descrição:
#
# * Poster_Link : Contém um link para a imagem do poster do filme disponibilizado pela Amazon
# * Series_Title : O nome do filme
# * Released_Year : Ano de Lançamento
# * Certificate : Classificação indicativa, no caso do DataFrame, é baseado no CBFC (Central Board of Film Certification), da Índia.
# * Runtime : Tempo de duração, em minutos
# * Genre : Gênero
# * IMDB_Rating : Avaliação do filme no site do IMDB
# * Overview : Sinopse do filme
# * Meta_Score: Nota do filme
# * Star1, Star2, Star3, Star4 : Nome das estrelas principais do filme
# * No_of_Votes : Número total de votos no IMDB
# * Gross : Dinheiro arrecadado pela bilheteria

# %% [markdown]
# ##**Refletindo sobre o DataFrame**
#
#
#
# ---
#
# Os protagonistas da investigação serão as colunas do DataFrame. Com os dados que elas nos fornecem podemos levantar algumas perguntas:
#
# * Qual período de anos possui as maiores notas e maiores bilheterias? Existiu um "período de ouro" nessa lista?
# * Qual o gênero mais popular?
# * Qual a relação entre a quantidade de votos e a nota do filme? Filmes com mais votos tendem a ter notas mais altas?
# * Filmes mais rentáveis possuem notas maiores?
# * Qual gênero mais arrecadou bilheteria?
# * Quais são os atores que mais aparecem?
# * Quantos filmes de animação aparecem na lista? Qual sua proporção de bilheteria e notas em relação aos outros filmes?
# * Qual classificação indicativa aparece mais?
#
# Algumas dessas perguntas foram geradas através de ajuda de IA a fim de aprofundar o pensamento analítico.
# Com essas perguntas, vamos começar a exploração.

# %% [markdown]
# #**Filtrando e tratando dados**
#
# ---
#
# Vamos retomar novamente as informações de nosso DataFrame

# %%
#Analisando a quantidade de informações

df_imdb_top.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %% [markdown]
# É possível notar que as colunas *Certificate*, *Meta_Score* e *Gross* possuem dados nulos, o que pode influenciar na qualidade da análise, para isso, irei fazer o tratamento desses dados. Começarei Certificate pois ele tem um tratamento extra a ser feito.

# %% [markdown]
# ###**Lidando com a coluna Certificate**
#
# Além da presença de dados nulos, para que a qualidade dos dados se volte para uma realidade brasileiro, eu sugeri uma mudança na coluna Certificate.
#
# **Certificate** nada mais é que a Classificação Indicativa. No caso dessa base de dados, desenvolvida por um professor em uma universidade na Índia, a classificação está voltada para aquele país.
#
# Para garantir a relevância dos dados para o contexto brasileiro, proponha uma adequação na coluna 'Certificate'. A classificação indicativa original, baseada no sistema indiano (CBFC), não possui uma equivalência direta com o sistema brasileiro. A adaptação da classificação indicativa é fundamental para que os dados reflitam a realidade brasileira e possam ser utilizados em análises e estudos mais precisos sobre o mercado cinematográfico nacional.
#
# Criamos um DataFrame auxiliar em formato Excel, contendo a mesma ordem de filmes do DataFrame principal e uma nova coluna com a classificação indicativa brasileira correspondente. Essa nova coluna será utilizada para substituir a coluna 'Certificate' original, proporcionando informações mais precisas e relevantes para o público brasileiro.
#
# Vamos importar esse novo DataFrame:

# %%
#Importante o DataFrame

imdb_certificatebrazil_url = '/content/drive/MyDrive/IMDBTop1000_BrazilianCertificate_DataSet.xlsx'

df_imdb_certificate_brazil = pd.read_excel(imdb_certificatebrazil_url)

# %%
df_imdb_certificate_brazil
# Out:
#                  Series_Title Certificate_Brazilian
# 0    The Shawshank Redemption                    16
# 1               The Godfather                    14
# 2             The Dark Knight                    12
# 3      The Godfather: Part II                    14
# 4                12 Angry Men                 Livre
# ..                        ...                   ...
# 995    Breakfast at Tiffany's                 Livre
# 996                     Giant                 Livre
# 997     From Here to Eternity                    14
# 998                  Lifeboat                    12
# 999              The 39 Steps                    12
#
# [1000 rows x 2 columns]

# %%
#Substituindo o a Coluna Certificate do ddf_imdb_top para a Coluna Certificate Brazilian do df_imdb_certificate_brazil
#Unindo os dois df usando o Series_Title como  chave

df_imdb_top = pd.merge(df_imdb_top, df_imdb_certificate_brazil, on='Series_Title')

# %%
df_imdb_top
# Out:
#                                             Poster_Link  \
# 0     https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1     https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2     https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3     https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4     https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ...                                                 ...
# 997   https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 998   https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 999   https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 1000  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 1001  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                   Series_Title Released_Year Certificate  Runtime  \
# 0     The Shawshank Redemption          1994           A  142 min
# 1                The Godfather          1972           A  175 min
# 2              The Dark Knight          2008          UA  152 min
# ...

# %%
#Substituindo as informações do Certificate pelas informações Certificate_Brazilian

df_imdb_top['Certificate'] = df_imdb_top['Certificate_Brazilian']

# %%
#Por fim, podemos excluir a Certificate_Brazilian

df_imdb_top.drop('Certificate_Brazilian', axis = 1, inplace = True)

# %%
#Vamos conferir se todos os valores nulos da coluna Certificate sumiram

df_imdb_top.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate        0
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       159
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            170
# dtype: int64

# %%
#DataFrame após o tratamento com o Certificate

df_imdb_top
# Out:
#                                             Poster_Link  \
# 0     https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1     https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2     https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3     https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4     https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ...                                                 ...
# 997   https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 998   https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 999   https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 1000  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 1001  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                   Series_Title Released_Year Certificate  Runtime  \
# 0     The Shawshank Redemption          1994          16  142 min
# 1                The Godfather          1972          14  175 min
# 2              The Dark Knight          2008          12  152 min
# ...

# %% [markdown]
# ###**Lidando com Meta_Score e Gross**
#
# Essas duas colunas passarão pelo mesmo tratamento.
# Uma das alternativas seria remover todas as linhas, mas isso afetaria nossa análise com outras colunas, para isso, irei substituir todos os valores nulos por 0.
#
# É possível refutar essa solução quando tivermos que usar os dados dessas duas colunas para calculo, já que o número 0 irá atrapalhar. Mas podemos ignorar esses valores com zero quando precisarmos.

# %%
#Substituindo os valores nulos por zero

df_imdb_top = df_imdb_top.fillna(0)

# %%
#Verificando

df_imdb_top.isnull().sum()
# Out:
# Poster_Link      0
# Series_Title     0
# Released_Year    0
# Certificate      0
# Runtime          0
# Genre            0
# IMDB_Rating      0
# Overview         0
# Meta_score       0
# Director         0
# Star1            0
# Star2            0
# Star3            0
# Star4            0
# No_of_Votes      0
# Gross            0
# dtype: int64

# %%
df_imdb_top
# Out:
#                                             Poster_Link  \
# 0     https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1     https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2     https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3     https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4     https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ...                                                 ...
# 997   https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 998   https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 999   https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 1000  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 1001  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                   Series_Title Released_Year Certificate  Runtime  \
# 0     The Shawshank Redemption          1994          16  142 min
# 1                The Godfather          1972          14  175 min
# 2              The Dark Knight          2008          12  152 min
# ...

# %% [markdown]
# #**Iniciando a análise exploratória**
#
#
# ---
#
# Vamos retomar as perguntas levantadas anteriormente:
#
# * Qual período de anos possui as maiores notas e maiores bilheterias? Existiu um "período de ouro" nessa lista?
# * Qual o gênero mais popular?
# * Quais são os atores que mais aparecem?
# * Quantos filmes de animação aparecem na lista? Qual sua proporção de bilheteria e notas em relação aos outros filmes?
# * Qual classificação indicativa aparece mais?

# %% [markdown]
# ###**Qual período de anos possui as maiores notas e maiores bilheterias? Existiu um "período de ouro" nessa lista?**

# %%
#Descobrindo o ano mais antigo e mais recente da coluna Released_Year
#Para isso, terei que fazer um tratamento na coluna, pois um dos valores é PG, o que impossibilita a analise que deve ser feita apenas ocm número
#Eis a linha com o valor PG na Released_Year

df_imdb_top[df_imdb_top['Released_Year'] == 'PG']
# Out:
#                                            Poster_Link Series_Title  \
# 968  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
#
#     Released_Year Certificate  Runtime                      Genre  \
# 968            PG       Livre  140 min  Adventure, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 968          7.6  NASA must devise a strategy to return Apollo 1...
#
#      Meta_score    Director      Star1        Star2        Star3        Star4  \
# 968        77.0  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      No_of_Votes        Gross
# 968       269197  173,837,933

# %%
#Fazendo a substituição
#De acordo com o próprio site do IMDB, o filme foi lançado em 1995

df_imdb_top.loc[968, 'Released_Year'] = '1995'

# %%
#Vamos fazer a conversão da coluna agora

df_imdb_top['Released_Year'] = df_imdb_top['Released_Year'].astype(int)

# %%
#Encontrando o ano mais antigo e recente

ano_mais_recente = df_imdb_top['Released_Year'].max()
ano_mais_antigo = df_imdb_top['Released_Year'].min()

print(f'O ano mais antigo é : {ano_mais_antigo} e o mais recente é: {ano_mais_recente}')
# Out:
# O ano mais antigo é : 1920 e o mais recente é: 2020

# %%
#Com isso, posso definir um intervalor de anos
#Para não ficar muito longo, irei fazer intervalos de 20 anos.

#1920 - 1939
#1940 - 1959
#1960 - 1979
#1980 - 1999
#2000 - 2020

faixa_de_anos = [1920, 1940, 1960, 1980, 2000, 2020]

df_imdb_top['Faixa_Anos'] = pd.cut(df_imdb_top['Released_Year'], bins = faixa_de_anos, labels = ['1920-1939', '1940-1959', '1960-1979', '1980-1999', '2000-2020'])

# %%
#Convertendo a coluna Gross para float

df_imdb_top["Gross"] = pd.to_numeric(df_imdb_top["Gross"].str.replace(",", "").str.strip(), errors="coerce").fillna(0)

# %%
#Criando os filtros da coluna Gross com a separação dos anos e evitando os zeros

filmes_1920_1939 = df_imdb_top[(df_imdb_top['Faixa_Anos'] == '1920-1939') & (df_imdb_top['Gross'] >  0)]
filmes_1940_1959 = df_imdb_top[(df_imdb_top['Faixa_Anos'] == '1940-1959') & (df_imdb_top['Gross'] >  0)]
filmes_1960_1979 = df_imdb_top[(df_imdb_top['Faixa_Anos'] == '1960-1979') & (df_imdb_top['Gross'] >  0)]
filmes_1980_1999 = df_imdb_top[(df_imdb_top['Faixa_Anos'] == '1980-1999') & (df_imdb_top['Gross'] >  0)]
filmes_2000_2020 = df_imdb_top[(df_imdb_top['Faixa_Anos'] == '2000-2020') & (df_imdb_top['Gross'] >  0)]

# %%
#Criando as somas e médias

soma_gross_1920_1939 = filmes_1920_1939['Gross'].sum()
media_gross_1920_1939 = filmes_1920_1939['Gross'].mean()
soma_gross_1940_1959 = filmes_1940_1959['Gross'].sum()
media_gross_1940_1959 = filmes_1940_1959['Gross'].mean()
soma_gross_1960_1979 = filmes_1960_1979['Gross'].sum()
media_gross_1960_1979 = filmes_1960_1979['Gross'].mean()
soma_gross_1980_1999 = filmes_1980_1999['Gross'].sum()
media_gross_1980_1999 = filmes_1980_1999['Gross'].mean()
soma_gross_2000_2020 = filmes_2000_2020['Gross'].sum()
media_gross_2000_2020 = filmes_2000_2020['Gross'].mean()

# %%
#Criando um df com as médias e somas

data_frame_bilheteria = [
    ('1920-1939', soma_gross_1920_1939, media_gross_1920_1939),
    ('1940-1959', soma_gross_1940_1959, media_gross_1940_1959),
    ('1960-1979', soma_gross_1960_1979, media_gross_1960_1979),
    ('1980-1999', soma_gross_1980_1999, media_gross_1980_1999),
    ('2000-2020', soma_gross_2000_2020, media_gross_2000_2020)
    ]

df_bilheteria = pd.DataFrame(data_frame_bilheteria, columns=['Intervalo_Anos', 'Somas', 'Médias'])

# %%
df_bilheteria
# Out:
#   Intervalo_Anos         Somas        Médias
# 0      1920-1939  3.356159e+08  1.243022e+07
# 1      1940-1959  6.306943e+08  1.167952e+07
# 2      1960-1979  5.116282e+09  4.872650e+07
# 3      1980-1999  1.403129e+10  6.074151e+07
# 4      2000-2020  3.642374e+10  8.776804e+07

# %%
df_bilheteria.plot(x = 'Intervalo_Anos', y = 'Médias', kind='barh')
# Out:
# <Axes: ylabel='Intervalo_Anos'>

# %%
df_bilheteria.plot(x = 'Intervalo_Anos', y = 'Somas', kind='barh', color = 'purple')
# Out:
# <Axes: ylabel='Intervalo_Anos'>

# %% [markdown]
# **<h3>Resultado<h3>**
#
#
# ---
#
#
#
# É importante ressaltar que a presença de valores influenciou um pouco dos resultados, mas é nítido que o *boom* do cinema está entre os anos 2000 a 2020. Isso pela facilidade de acesso ao cinema tanto pelo aumento da popularidade. Outro fator importante é o acesso a informação.
#
# Percebe-se que as eras mais antigas tem as colunas mais baixas, minha sugestão é que os investimentos com cinema antigamente eram bem menores. Outra sugestão que não existe informações completas sobre a bilheteria de antigamente.

# %% [markdown]
# ###**Qual o gênero mais popular?**

# %%
df_imdb_top
# Out:
#                                             Poster_Link  \
# 0     https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1     https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2     https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3     https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4     https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ...                                                 ...
# 997   https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 998   https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 999   https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 1000  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 1001  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                   Series_Title  Released_Year Certificate  Runtime  \
# 0     The Shawshank Redemption           1994          16  142 min
# 1                The Godfather           1972          14  175 min
# 2              The Dark Knight           2008          12  152 min
# ...

# %%
#Transformando a coluna Genre em uma lista, garantindo que todos os elementos estejam separados

generos_lista = df_imdb_top['Genre'].str.split(', ').explode().tolist()

# %%
generos_lista
# Out:
# ['Drama',
#  'Crime',
#  'Drama',
#  'Action',
#  'Crime',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Western',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Sci-Fi',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Drama',
#  'Biography',
#  'Drama',
#  'History',
#  'Comedy',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  'Crime',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Family',
#  'Drama',
#  'War',
#  'Crime',
#  'Drama',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Drama',
#  'Mystery',
#  'Action',
# ...

# %%
#Usando o Counter para encontrar os gêneros mais popular e calcular a porcentagem

from collections import Counter

genero_mais_popular = Counter(generos_lista).most_common(1)[0][0]
qnt_vezes = Counter(generos_lista).most_common(1)[0][1]

linhas, colunas = df_imdb_top.shape
porcentagem_gen_popular = round((qnt_vezes/linhas)* 100, 2)

# %% [markdown]
# **<h3>Resultado<h3>**

# %%
print(f'O gênero mais popular é o {genero_mais_popular} e aparece {qnt_vezes} vezes')
print(f'Ele equivale a {porcentagem_gen_popular}% da lista')
# Out:
# O gênero mais popular é o Drama e aparece 726 vezes
# Ele equivale a 72.46% da lista

# %% [markdown]
# ###**Quais são os atores que mais aparecem?**

# %%
#Convertendo as colunas de atores em uma lista

lista1 = df_imdb_top['Star1'].values.tolist()
lista2 = df_imdb_top['Star2'].values.tolist()
lista3 = df_imdb_top['Star3'].values.tolist()
lista4 = df_imdb_top['Star4'].values.tolist()

lista_atores = lista1 + lista2 + lista3 + lista4

# %%
#Encontrando os atores mais populares e os colocando em um top 10

ator_popular = Counter(lista_atores).most_common(10)

nomes_atores = [item[0] for item in ator_popular]
qnt_vezes_ator = [item[1] for item in ator_popular]

posicao = 1
print('Os 10 atores mais populares:')
for nomes,qnt in zip(nomes_atores,qnt_vezes_ator):
  print(f'{posicao}º : {nomes}, {qnt}')
  posicao += 1
# Out:
# Os 10 atores mais populares:
# 1º : Robert De Niro, 17
# 2º : Tom Hanks, 14
# 3º : Al Pacino, 13
# 4º : Brad Pitt, 12
# 5º : Clint Eastwood, 12
# 6º : Christian Bale, 11
# 7º : Leonardo DiCaprio, 11
# 8º : Matt Damon, 11
# 9º : James Stewart, 10
# 10º : Humphrey Bogart, 9

# %% [markdown]
# **<h3>Resultado<h3>**
#
# Destaca-se a presente de massiva maioria de atores de filmes norte-americanos. Abaixo, é possível ver que a presença de atrizes ocorre apenas em 15º, sendo essa a Scarlett Johansson

# %%
#Lista para mostrar atrizes

Counter(lista_atores).most_common(20)
# Out:
# [('Robert De Niro', 17),
#  ('Tom Hanks', 14),
#  ('Al Pacino', 13),
#  ('Brad Pitt', 12),
#  ('Clint Eastwood', 12),
#  ('Christian Bale', 11),
#  ('Leonardo DiCaprio', 11),
#  ('Matt Damon', 11),
#  ('James Stewart', 10),
#  ('Humphrey Bogart', 9),
#  ('Ethan Hawke', 9),
#  ('Johnny Depp', 9),
#  ('Denzel Washington', 9),
#  ('Michael Caine', 9),
#  ('Scarlett Johansson', 9),
#  ('Aamir Khan', 8),
#  ('Harrison Ford', 8),
#  ('Morgan Freeman', 7),
#  ('Toshirô Mifune', 7),
#  ('Russell Crowe', 7)]

# %% [markdown]
# ###**Quantos filmes de animação aparecem na lista? Qual sua proporção de bilheteria e notas em relação aos outros filmes?**

# %%
#Lendo novamente a lista de generos

generos_lista
# Out:
# ['Drama',
#  'Crime',
#  'Drama',
#  'Action',
#  'Crime',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Western',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Sci-Fi',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Drama',
#  'Biography',
#  'Drama',
#  'History',
#  'Comedy',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  'Crime',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Family',
#  'Drama',
#  'War',
#  'Crime',
#  'Drama',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Drama',
#  'Mystery',
#  'Action',
# ...

# %%
#Contando a quantidade de

num_animacoes = generos_lista.count('Animation')

print(f'O gênero Animation aparece {num_animacoes} vezes na lista')
# Out:
# O gênero Animation aparece 82 vezes na lista

# %%
#Fazendo comparação com o total de gêneros

linhas, colunas = df_imdb_top.shape
porcentagem_animacao_total = round((num_animacoes/linhas) * 100, 2)

print(f'A quantidade de Animações presentes na lista representa {porcentagem_animacao_total}% do total de filmes')
# Out:
# A quantidade de Animações presentes na lista representa 8.18% do total de filmes

# %%
#Analisando a faixa etária dos filmes de animação

df_animacoes_classificacao = df_imdb_top[df_imdb_top['Genre'].str.contains('Animation', case=False, na=False)]
df_animacoes_classificacao['Certificate'].value_counts()
# Out:
# Certificate
# Livre    51
# 12       10
# 10        9
# 14        5
# 16        5
# SC        2
# Name: count, dtype: int64

# %% [markdown]
# **<h3>Resultado<h3>**
#
#
# ---
#
#
#
# A incidência do gênero animação representa quase 1/10 dos filmes na lista. É possível dizer que as animações que se destacaram e entraram na lista "furaram" suas bolhas e atingiram outros públicos além do infantil (mesmo que o gênero animação não seja EXCLUSIVAMENTE infantil), o que permitiu que esses tivessem espaço na classificação
#
# Em comparação com o gênero Drama, que é o mais popular, a incidência das animações é aproximadamente 8 vezes menor.
#
# Outra questão que pode ser teorizada é que animações ainda sofrem certa "resistência" dos usuários que associam o gênero a justamente ao público infantil, e também há resistência dos executivos em investirem em filmes de animações com classificações indicativas mais altas com medo de não atraírem público ou sofrerem críticas por escolherem um gênero vinculado a crianças para contar com temas adultos.

# %% [markdown]
# ###**Qual classificação indicativa aparece mais?**

# %%
#Incidência de classificações indicativas

df_imdb_top['Certificate'].value_counts()
# Out:
# Certificate
# 14       273
# 12       204
# Livre    179
# 16       171
# SC        72
# 18        65
# 10        38
# Name: count, dtype: int64

# %% [markdown]
# #**Considerações Finais**
#
# ---
#
# Muitos resultados aqui obtidos trouxeram algumas surpresas, mas apesar de não possuir uma conclusão final, o maior objetivo desse projeto era usar o DataFrame como um uma espécie de experimentos para testar habilidades.
#
# Esotu a disposição para receber sugestões e dicas de como melhorar 🙂
#
# Por fim, deixo aqui o link com o DataSet criado com as classificações indicativas brasileiras
#
# [IMDB TOP 1000 BRAZILIAN CERTIFICATE](https://www.kaggle.com/datasets/vanessanforin/imdb-top-1000-movies-with-brazilian-certificate)
